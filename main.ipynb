# %%
# Defining menu & resources
menu = {
    "espresso": {
        "ingredients": {
            "water": 50,
            "milk": 0,
            "coffee": 20
        },
        "price": 1.5
    },
    "latte": {
        "ingredients": {
            "water": 150,
            "milk": 200,
            "coffee": 25
        },
        "price": 2.5
    },
    "cappuccino": {
        "ingredients": {
            "water": 250,
            "milk": 100,
            "coffee": 25
        },
        "price": 3.0
    }
}

resources = {
    "water": 1000,
    "milk": 1000,
    "coffee": 100,
    "money": 0
}

while True:

  # Ask user for order
  order = input("What would you like to order?\nCappuccino, Latte or Espresso?\n").lower()

  # Special cases
  if order == 'off':
    break
  elif order == 'report':
    print(f"\nWe have the following resources:\nWater: {resources['water']}ml\nMilk: {resources['milk']}ml\nCoffee: {resources['coffee']}g\nMoney: ${resources['money']}\n")
    continue

  # Check resources
  if resources['water'] >= menu[order]['ingredients']['water']:
    if resources['milk'] >= menu[order]['ingredients']['milk']:
      if resources['coffee'] >= menu[order]['ingredients']['coffee']:

        # Ask and calculate payment
        print(f"\nPay ${menu[order]['price']}\n")

        print("Insert coins")
        p = int(input("Insert pennies\n"))
        n = int(input("Insert nickels\n"))
        d = int(input("Insert dimes\n"))
        q = int(input("Insert quarters\n"))
        total = (p * 0.01) + (n * 0.05) + (d * 0.10) + (q * 0.25)

        if total == menu[order]['price']:
          # Make coffee
          resources['water'] = resources['water'] - menu[order]['ingredients']['water']
          resources['coffee'] = resources['coffee'] - menu[order]['ingredients']['coffee']
          resources['milk'] = resources['milk'] - menu[order]['ingredients']['milk']
          resources['money'] = resources['money'] + menu[order]['price']
          print("\nTransaction successful. Here is your coffee!")

        elif total > menu[order]['price']:
          # Make coffee
          resources['water'] = resources['water'] - menu[order]['ingredients']['water']
          resources['coffee'] = resources['coffee'] - menu[order]['ingredients']['coffee']
          resources['milk'] = resources['milk'] - menu[order]['ingredients']['milk']
          resources['money'] = resources['money'] + menu[order]['price']
          print("\nTransaction successful. Here is your coffee!")

          # Return change
          change = total - menu[order]['price']
          print(f"\nYou have inserted extra coins. Here is your change ${change}\n")

        else:
          print("\nPayment not complete. Cannot process order.\n")
      else:
          print("\nResources insufficient! There is not enough coffee!\n")
    else:
      print("\nResources insufficient There is not enough milk!\n")
  else:
    print("\nResources insufficient! There is not enough water!\n")
# Out:
# What would you like to order?
# Cappuccino, Latte or Espresso?
# report
#
# We have the following resources:
# Water: 1000ml
# Milk: 1000ml
# Coffee: 100g
# Money: $0
#
# What would you like to order?
# Cappuccino, Latte or Espresso?
# espresso
#
# Pay $1.5
#
# Insert coins
# Insert pennies
# 0
# Insert nickels
# 0
# Insert dimes
# 0
# Insert quarters
# 0
# Payment not complete. Cannot process order.
# What would you like to order?
# Cappuccino, Latte or Espresso?
# off
